# %% [markdown]
# # Data Analysis on Real world Dataset on IPL cricket 2008-2019
#
# In This project we are going to work on the **real world dataset of iplcircket from 2017-2019** with this data set we can have a good partice on the data cleaning and visualisation.This data set was obtained from the **kaggle** link - https://www.kaggle.com/nowke9/ipldata.
#
# With this dataset we are going find some of the insites and statistical analysis with this data like we are going to ask many questions with this dataset like what was the winning percentage of teams in ipl and so on.
#
# In this project were are going to use **pandas,numpy,seaborn,matpolit and some important functions in python.**
#
# This project is my learning from the course [Data Analysis with Python: Zero to Pandas](zerotopandas.com).

# %% [markdown]
# ## Downloading the Dataset
#
# **Downloading the IPL-cricket dataset**
#
# Here we downolad the dataset of iplcircket from 2008-2019 from kaggle.we pass in url and download with the kaggle username and api.

# %%
# !pip install jovian opendatasets --upgrade --quiet

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
dataset_url = 'https://www.kaggle.com/nowke9/ipldata'

# %%
import opendatasets as od
od.download(dataset_url)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: kiransubramanians
# Your Kaggle Key: ········
# 100%|██████████| 1.20M/1.20M [00:00<00:00, 59.9MB/s]
# ...

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
data_dir = './ipldata'

# %%
import os
os.listdir(data_dir)
# Out:
# ['deliveries.csv', 'matches.csv']

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "Zero-Pandas-RealLife-Dataset-of-IPLcircket"

# %%
# !pip install jovian --upgrade -q

# %%
import jovian

# %%
jovian.commit(project=project_name)
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %% [markdown]
# ## Data Preparation and Cleaning
#
# In this Section we will get to know about the dataset and get an idea of the data set and Prepare the data to be analysis it by cleaning it by taking only the necessary column from the data set and clean the empty data and process the data
# by this we will be ready to visualise the data.

# %%
import pandas as pd

# %%
circket_df=pd.read_csv("./ipldata/matches.csv")
circket_df
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
deliveries_df=pd.read_csv("./ipldata/deliveries.csv")
deliveries_df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
circket_df.shape
# Out:
# (756, 18)

# %%
circket_df.head(10)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai  2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore  2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune  2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai  2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
circket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
#in this we convert the date with dtype object to datetime dtype
circket_df['date']=pd.to_datetime(circket_df['date'])
circket_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    datetime64[ns]
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
# ...

# %%
deliveries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 179078 entries, 0 to 179077
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   match_id          179078 non-null  int64
#  1   inning            179078 non-null  int64
#  2   batting_team      179078 non-null  object
#  3   bowling_team      179078 non-null  object
#  4   over              179078 non-null  int64
#  5   ball              179078 non-null  int64
#  6   batsman           179078 non-null  object
#  7   non_striker       179078 non-null  object
#  8   bowler            179078 non-null  object
#  9   is_super_over     179078 non-null  int64
#  10  wide_runs         179078 non-null  int64
#  11  bye_runs          179078 non-null  int64
#  12  legbye_runs       179078 non-null  int64
#  13  noball_runs       179078 non-null  int64
#  14  penalty_runs      179078 non-null  int64
#  15  batsman_runs      179078 non-null  int64
# ...

# %%
circket_df.winner.unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', nan, 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
circket_df.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
#in this we take only the needed columns to anothor dataframe
needed_df=circket_df[['id','season','city','date','team1','team2','toss_winner','toss_decision','result','winner','win_by_runs','win_by_wickets','player_of_match','venue' ]]

# %%
#since we already have id we drop the index
needed_df.reset_index(drop=True)
needed_df
# Out:
#         id  season           city       date                        team1  \
# 0        1    2017      Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune 2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot 2017-04-07                Gujarat Lions
# 3        4    2017         Indore 2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore 2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...        ...                          ...
# 751  11347    2019         Mumbai 2019-05-05        Kolkata Knight Riders
# 752  11412    2019        Chennai 2019-07-05          Chennai Super Kings
# 753  11413    2019  Visakhapatnam 2019-08-05          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam 2019-10-05               Delhi Capitals
# 755  11415    2019      Hyderabad 2019-12-05               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
needed_df.result.unique()
# Out:
# array(['normal', 'tie', 'no result'], dtype=object)

# %%
# we are going to clean by some matches do not have the result with them we are going to drop them.
needed_df.loc[needed_df['result'] == 'no result']
# Out:
#         id  season       city       date                        team1  \
# 300    301    2011      Delhi 2011-05-21             Delhi Daredevils
# 545    546    2015  Bangalore 2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bangalore 2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru 2019-04-30  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# 570  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 744             Rajasthan Royals             Rajasthan Royals         field
#
#         result winner  win_by_runs  win_by_wickets player_of_match  \
# 300  no result    NaN            0               0             NaN
# 545  no result    NaN            0               0             NaN
# ...

# %%
needed_df.drop([301,546,571],inplace=True)
needed_df.loc[needed_df['result'] == 'no result']
# Out:
# /srv/conda/envs/notebook/lib/python3.8/site-packages/pandas/core/frame.py:4162: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#         id  season       city       date                        team1  \
# 300    301    2011      Delhi 2011-05-21             Delhi Daredevils
# 545    546    2015  Bangalore 2015-04-29  Royal Challengers Bangalore
# 570    571    2015  Bangalore 2015-05-17             Delhi Daredevils
# 744  11340    2019  Bengaluru 2019-04-30  Royal Challengers Bangalore
#
#                            team2                  toss_winner toss_decision  \
# 300                Pune Warriors             Delhi Daredevils           bat
# 545             Rajasthan Royals             Rajasthan Royals         field
# ...

# %%
needed_df.head(10)
# Out:
#    id  season       city       date                        team1  \
# 0   1    2017  Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune 2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot 2017-04-07                Gujarat Lions
# 3   4    2017     Indore 2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore 2017-04-08  Royal Challengers Bangalore
# 5   6    2017  Hyderabad 2017-04-09                Gujarat Lions
# 6   7    2017     Mumbai 2017-04-09        Kolkata Knight Riders
# 7   8    2017     Indore 2017-04-10  Royal Challengers Bangalore
# 8   9    2017       Pune 2017-04-11             Delhi Daredevils
# 9  10    2017     Mumbai 2017-04-12          Sunrisers Hyderabad
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# In this section we are going to get the insigts,interesting statistics and better understanding the data
#
# ##### we are going to draw some graphs and explain the details of the data

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %%
needed_df.describe()
# Out:
#                  id       season  win_by_runs  win_by_wickets
# count    756.000000   756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    13.283069        3.350529
# std     3464.478148     3.366895    23.471144        3.387963
# min        1.000000  2008.000000     0.000000        0.000000
# 25%      189.750000  2011.000000     0.000000        0.000000
# 50%      378.500000  2013.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    19.000000        6.000000
# max    11415.000000  2019.000000   146.000000       10.000000

# %% [markdown]
# ##### Below we can see that how the teams won the matches in each season.

# %%
sns.barplot(x="season", y="win_by_runs", data=needed_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='win_by_runs'>

# %% [markdown]
# In above Bar graph you can see that the years in which how team have won the matches as you can see in the year 2013 the teams have won with higher run difference from this we come to the conclusion that most of matches did not have a nailbaiting end in this year.

# %%
sns.barplot(x="season", y="win_by_wickets", data=needed_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='win_by_wickets'>

# %% [markdown]
# #### Here You can see that the teams who won the toss if they win then how much runs differnce they are wining

# %%
sns.scatterplot(data=needed_df, x="win_by_runs", y="toss_winner")
# Out:
# <AxesSubplot:xlabel='win_by_runs', ylabel='toss_winner'>

# %% [markdown]
# From the above you can see that most of the team won when  run was around 20 to 40

# %% [markdown]
# You can see that most of the team have win by runs with difference of 20 to 0

# %%
sns.boxplot(x="season", y="winner",data=needed_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='winner'>

# %% [markdown]
# you can see that each team and winning in the each season

# %% [markdown]
# #### Find the team which have won the match with heighesit wicket differences

# %%
sns.catplot(
    data=needed_df, kind="bar",
    x="win_by_wickets", y="winner"
)

# %% [markdown]
# As you can observe that the team delhi and kochi have won with the most won the matches with most wickets difference

# %% [markdown]
# #### From  this you could find that how team won the matches with most run difference

# %%
sns.boxenplot(x="season", y="win_by_runs",
              color="r", 
              scale="linear", data=needed_df)
# Out:
# <AxesSubplot:xlabel='season', ylabel='win_by_runs'>

# %% [markdown]
# You some team have won the matches with the runs more than 140 runs

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %% [markdown]
# ## Asking and Answering Questions
#
# In this section we will try to ask some question on the data set and try to answer them

# %% [markdown]
# #### Q1: Lets find which team have won many matches from ipl 2017 to 2019

# %%
needed_df
# Out:
#         id  season           city       date                        team1  \
# 0        1    2017      Hyderabad 2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune 2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot 2017-04-07                Gujarat Lions
# 3        4    2017         Indore 2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore 2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...        ...                          ...
# 751  11347    2019         Mumbai 2019-05-05        Kolkata Knight Riders
# 752  11412    2019        Chennai 2019-07-05          Chennai Super Kings
# 753  11413    2019  Visakhapatnam 2019-08-05          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam 2019-10-05               Delhi Capitals
# 755  11415    2019      Hyderabad 2019-12-05               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
Max_number_of_matches=needed_df['winner'].value_counts()[:1].index.tolist()
Max_number_of_matches
# Out:
# ['Mumbai Indians']

# %%
print ("The Team  "+Max_number_of_matches[0]+" have won {} mactches from ipl 2008-2019 they won the most number of matches till now".format(needed_df['winner'].value_counts().max()))
# Out:
# The Team  Mumbai Indians have won 109 mactches from ipl 2008-2019 they won the most number of matches till now

# %% [markdown]
# ###### AS  you could see the above question is to find team who have won the most number of matches in ipl histroy
# Solution:
#     we took the column "winner" and found the max count and took the index ,so we got the answer

# %% [markdown]
# #### Q2: lets try to find which team have won most number of toss in season 2018 and most number of winning of the year

# %%
season_2018=needed_df.loc[needed_df["season"]==2018]

# %%
df=season_2018["toss_winner"].value_counts()[:1].index.tolist()

# %%
print("The Team " +df[0]+" have won the maximum number of toss and the team {} have won most of the matches in season 2018".format
     (season_2018['winner'].value_counts()[:1].index.tolist()))
# Out:
# The Team Chennai Super Kings have won the maximum number of toss and the team ['Chennai Super Kings'] have won most of the matches in season 2018

# %% [markdown]
# #### Q3:  Lets try to find persentage that thoes teams who have won the toss have won the match are lost the matches

# %%
data=needed_df.loc[needed_df["toss_winner"]==needed_df["winner"]]
data
# Out:
#         id  season           city       date                        team1  \
# 1        2    2017           Pune 2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot 2017-04-07                Gujarat Lions
# 3        4    2017         Indore 2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore 2017-04-08  Royal Challengers Bangalore
# 5        6    2017      Hyderabad 2017-04-09                Gujarat Lions
# ..     ...     ...            ...        ...                          ...
# 750  11346    2019         Mohali 2019-05-05          Chennai Super Kings
# 751  11347    2019         Mumbai 2019-05-05        Kolkata Knight Riders
# 753  11413    2019  Visakhapatnam 2019-08-05          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam 2019-10-05               Delhi Capitals
# 755  11415    2019      Hyderabad 2019-12-05               Mumbai Indians
#
#                       team2                  toss_winner toss_decision  \
# ...

# %%
#this the persentage of teams who have won the match as well as toss
total_teams=needed_df.shape[0]
teams_won=data.shape[0]
persentage=(teams_won*100)/total_teams
persentage
# Out:
# 51.98412698412698

# %%
print("The teams that won the toss will have {:.2f}% chance to win the match and {}% to lose the match".format(persentage,100-51.98))
# Out:
# The teams that won the toss will have 51.98% chance to win the match and 48.02% to lose the match

# %% [markdown]
# ##### As you can see that we have found the winning and lossing persentage of the teams based on toss
# soloution:
# get the teams that have won the toss as well as the match
# get the percentge

# %% [markdown]
# #### Q4: Lets try to find which team have won the match with heighest number of runs

# %%
bating=needed_df.loc[needed_df["toss_decision"]=='bat']

# %%
bating["win_by_runs"].max()
# Out:
# 111

# %%
result=bating.loc[needed_df["win_by_runs"]==111]["winner"]

# %%
print("The team {} have won the match with heighest number of runs in difference".format(result))
# Out:
# The team 295    Kings XI Punjab
# Name: winner, dtype: object have won the match with heighest number of runs in difference

# %% [markdown]
# ### you can see that team kings XI Punjab have won the match with the difference of  111 runs which heighest of all
# soloution
#
# locate the toss decision and get the maximum win by runs and get the winnin team

# %% [markdown]
# #### Q5: Lets find the place/venue where the team csk have won the most

# %%
answer=needed_df.loc[needed_df["winner"]=='Chennai Super Kings']
answer
# Out:
#         id  season           city       date                  team1  \
# 60      61    2008     Chandigarh 2008-04-19    Chennai Super Kings
# 66      67    2008        Chennai 2008-04-23    Chennai Super Kings
# 70      71    2008        Chennai 2008-04-26  Kolkata Knight Riders
# 73      74    2008      Bangalore 2008-04-28    Chennai Super Kings
# 86      87    2008          Delhi 2008-05-08       Delhi Daredevils
# ..     ...     ...            ...        ...                    ...
# 720  11316    2019         Jaipur 2019-11-04       Rajasthan Royals
# 724  11320    2019        Kolkata 2019-04-14  Kolkata Knight Riders
# 736  11332    2019        Chennai 2019-04-23    Sunrisers Hyderabad
# 745  11341    2019        Chennai 2019-01-05    Chennai Super Kings
# 754  11414    2019  Visakhapatnam 2019-10-05         Delhi Capitals
#
#                            team2            toss_winner toss_decision  result  \
# ...

# %%
res=answer["venue"].value_counts()[:1].index.tolist()
runs=answer["venue"].value_counts().max()
runs
most=answer.shape[0]

# %%
print ("The team Chennai Super Kings have won total of {} matches in which {} number of matches were won in their home venue ".format(most,runs)+res[0]+" ")
# Out:
# The team Chennai Super Kings have won total of 100 matches in which 34 number of matches were won in their home venue MA Chidambaram Stadium, Chepauk

# %% [markdown]
# ### As you can see we found the venue where the team Chennai super kings have won the most of the matches
#
# solution
# 1)get new dataframe with the only the csk winning rows
# 2)the get the max times winng venue by the given function

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %% [markdown]
# ## Inferences and Conclusion
#
# Thus we conclude this project with the above analysis that we came up with winning persentage of the teams with respective to the toss descision.
#
# we also say where the team CSK have won the most of the matches as venue.Such stuf we have answed five question
#
# with this project we could the basics of the data anlysis and understand better than before.

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ml/
# [jovian] Uploading notebook..
# [jovian] Capturing environment..
# [jovian] Committed successfully! https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ml/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %% [markdown]
# ## References and Future Work
# REFERNCE
# linkes
# {
# https://pandas.pydata.org/
# https://www.geeksforgeeks.org/
# }

# %%
jovian.commit(message="jovian version commit message",
              git_message="git commit message")
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'

# %%
# !git reflog
# Out:
# 6230efa (HEAD -> master, origin/master, origin/HEAD) HEAD@{0}: reset: moving to 6230efa3d722cdd38fad6485abaa0ca68cbaeda0
# 6230efa (HEAD -> master, origin/master, origin/HEAD) HEAD@{1}: clone: from https://jovian.ai/api/git/c641b61e688541a5bdd187caeab2705e_19.git

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..
# [jovian] Updating notebook "18eucs145/zero-pandas-reallife-dataset-of-iplcircket" on https://jovian.ai
# [jovian] Uploading notebook..
# [jovian] Uploading additional files...
# [jovian] Committed successfully! https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket
# 'https://jovian.ai/18eucs145/zero-pandas-reallife-dataset-of-iplcircket'
